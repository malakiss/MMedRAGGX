# %%
# !python ./train/open_clip/src/retrieve_clip_VQA.py \
    --img_root /content/yourpath/iu_xray/iu_xray/images \
    --train_json /content/yourpath/data/training/retriever/radiology/radiology_train.json \
    --eval_json /content/yourpath/data/training/retriever/radiology/radiology_val.json \
    --model_name_or_path hf-hub:thaottn/OpenCLIP-resnet50-CC12M \
    --checkpoint_path /content/yourpath/train/open_clip/src/logs/2025_11_20-20_37_06-model_hf-hub:thaottn-OpenCLIP-resnet50-CC12M-lr_0.0001-b_64-j_2-p_amp/checkpoints/epoch_360.pt \
    --output_path /content/yourpath/output_rag.json \
    --fixed_k 10
# Out:
# python3: can't open file '/content/./train/open_clip/src/retrieve_clip_VQA.py': [Errno 2] No such file or directory
